# %%
import pandas as pd
data=pd.read_pickle('corpus.pkl')
data
# Out:
#                                                 transcript         full_name
# ali      Ladies and gentlemen, please welcome to the st...          Ali Wong
# anthony  Thank you. Thank you. Thank you, San Francisco...  Anthony Jeselnik
# bill     [cheers and applause] All right, thank you! Th...         Bill Burr
# bo       Bo What? Old MacDonald had a farm E I E I O An...        Bo Burnham
# dave     This is Dave. He tells dirty jokes for a livin...    Dave Chappelle
# hasan    [theme music: orchestral hip-hop] [crowd roars...      Hasan Minhaj
# jim      [Car horn honks] [Audience cheering] [Announce...     Jim Jefferies
# joe      [rock music playing] [audience cheering] [anno...         Joe Rogan
# john     All right, Petunia. Wish me luck out there. Yo...      John Mulaney
# louis    Intro\nFade the music out. Let’s roll. Hold th...        Louis C.K.
# mike     Wow. Hey, thank you. Thanks. Thank you, guys. ...    Mike Birbiglia
# ricky    Hello. Hello! How you doing? Great. Thank you....     Ricky Gervais

# %%
hasan_text=data.transcript.loc['hasan']
hasan_text[:200]
# Out:
# '[theme music: orchestral hip-hop] [crowd roars] What’s up? Davis, what’s up? I’m home. I had to bring it back here. Netflix said, “Where do you want to do the special? LA, Chicago, New York?” I was li'

# %%
from collections import defaultdict
def markov_chain(text):
    words=text.split(' ')
    m_dict= defaultdict(list)

    for first_word,next_word in zip(words[0:-1],words[1:]) :
        m_dict[first_word].append(next_word)
        
    m_dict=m_dict
    return m_dict

# %%
hasan_dict = markov_chain(hasan_text)
hasan_dict
# Out:
# defaultdict(list,
#             {'[theme': ['music:'],
#              'music:': ['orchestral'],
#              'orchestral': ['hip-hop]'],
#              'hip-hop]': ['[crowd'],
#              '[crowd': ['roars]'],
#              'roars]': ['What’s'],
#              'What’s': ['up?', 'wild', 'your', 'Hasan-bye?”', 'that'],
#              'up?': ['Davis,', 'I’m', 'Is'],
#              'Davis,': ['what’s', 'California,', 'okay?', 'and'],
#              'what’s': ['up?',
#               'great?',
#               'your',
#               'important',
#               'going',
#               'your',
#               'about',
#               'right',
#               'up?'],
#              'I’m': ['home.',
#               'like,',
#               'so',
#               'the',
#               'not',
#               'picking',
#               'like,',
#               'fucked.',
#               'six,',
#               'turning',
#               'like,',
#               'like,',
#               'a',
#               'so',
#               'standing',
#               'like,',
#               'standing',
#               'in',
#               'like,',
#               'like,',
#               'like,',
#               'like,',
#               'livid.',
#               'like,',
#               'livid.',
#               'like,',
#               'like,',
#               'flying.',
#               'about',
#               'looking',
#               'like,',
#               'being',
#               'supposed',
#               'out',
#               'doing',
#               'going',
#               'standing',
#               'standing',
#               'never',
#               'losing',
#               'supposed',
#               'walking',
#               'going',
#               'looking',
#               'a',
#               'a',
#               'pissed,',
#               'fucking',
#               'looking',
#               'like,',
#               'asking',
#               'like,',
#               'equal.',
#               'equal.',
#               'JGL.',
#               'blessed.',
#               'crushing',
#               'trying',
#               'not',
#               'not',
#               'looking',
#               'like,',
#               'going',
#               'like,',
#               'walking',
#               'about',
#               'making',
#               'like,',
#               'laughing',
#               'crying.',
#               'like,',
#               'walking',
#               'going',
#               'going',
#               'scaling',
#               'biking',
#               'balancing',
#               'walking',
#               'about',
#               'like,',
#               'going',
#               'like,',
#               'flying',
#               'going',
#               'signing',
#               'signing',
#               'saying',
#               'waiting,',
#               'telling',
#               'mad',
#               'like,',
#               'walking',
#               'livid.',
#               'pissed.',
#               'practicing',
#               'like,',
#               'sitting',
#               'here?',
#               'here',
#               'trying',
#               'trying,',
#               'going',
#               'looking',
#               'so',
#               'like,',
#               'standing',
#               'like,',
#               'walking',
#               'not',
#               'a',
#               'walking',
#               'watching',
#               'sweating',
#               'nervous.',
#               'stuttering.',
#               'choking.',
#               'really',
#               'pooping',
#               'like,',
#               'like,',
#               'like…',
#               'sure',
#               'the'],
#              'home.': ['I', 'Father', 'And'],
#              'I': ['had',
#               'was',
#               'recently',
#               'need',
#               'got',
#               'don’t',
#               'don’t',
#               'want',
#               'hope',
#               'come',
#               'popped',
#               'never',
#               'want',
#               'think',
#               'grew',
#               'grew',
#               'would',
#               'don’t',
#               'have',
#               'get',
#               'would',
#               'would',
#               'love',
#               'know',
#               'listen',
#               'should',
#               'know',
#               'talk',
#               'think',
#               'just',
#               'was',
#               'have',
#               'look',
#               'was',
#               'wanted.',
#               'forget',
#               'brought',
#               'was',
#               'didn’t',
#               'would',
#               'wanted',
#               'realized',
#               'could',
#               'want',
#               'was',
#               'had',
#               'realized',
#               'don’t',
#               'just',
#               'want',
#               'was',
#               'was',
#               'missed',
#               'need',
#               'need',
#               'need',
#               'need',
#               'need',
#               'don’t',
#               'put',
#               'can',
#               'put',
#               'have',
#               'had',
#               'told',
#               'hated',
#               'was',
#               'was',
#               'was',
#               'remember',
#               'say',
#               'go',
#               'run',
#               'went',
#               'don’t',
#               'took',
#               'was',
#               'was',
#               'was',
#               'can',
#               'see',
#               'felt',
#               'see',
#               'have',
#               'have',
#               'went',
#               'grab',
#               'take',
#               'see',
#               'go',
#               'pick',
#               'hear',
#               'gave',
#               'was',
#               'had',
#               'didn’t',
#               'became',
#               'do.',
#               'got',
#               'heard',
#               'heard',
#               'didn’t',
#               'explain',
#               'know',
#               'know,',
#               'convinced',
#               'love',
#               'would',
#               'don’t',
#               'bet',
#               'promise',
#               'can’t',
#               'can’t',
#               'put',
#               'hear',
#               'did',
#               'got',
#               'can’t',
#               'resented',
#               'hated',
#               'couldn’t',
#               'was',
#               'had',
#               'ask',
#               'was',
#               'run,',
#               'grab',
#               'hear',
#               'see',
#               'realize',
#               'should',
#               'didn’t.',
#               'hear',
#               'reach',
#               'pull',
#               'look',
#               'was',
#               'was',
#               'actually',
#               'have',
#               'don’t',
#               'say',
#               'believe',
#               'honestly',
#               'don’t',
#               'know',
#               'understand.',
#               'fell',
#               'saw',
#               'run',
#               'was',
#               'was',
#               'just',
#               'was',
#               'love',
#               'know',
#               'know',
#               'hate',
#               'had',
#               'had',
#               'had',
#               'was',
#               'could',
#               'lacked',
#               'was',
#               'mean?',
#               'bike',
#               'was',
#               'like?',
#               'like',
#               'will.',
#               'will',
#               'was',
#               'was',
#               'hit',
#               'mean?',
#               'look',
#               'love',
#               'don’t',
#               'am?',
#               'can',
#               'was',
#               'said,',
#               'was',
#               'was',
#               'have',
#               'want',
#               'look',
#               'hear',
#               'was',
#               'was',
#               'was',
#               'said',
#               'was',
#               'had',
#               'could',
#               'disagree',
#               'respect',
#               'will',
#               'ran',
#               'was',
#               'would',
#               'live',
#               'die,',
#               'had',
#               'put',
#               'jump',
#               'jump',
#               'somehow',
#               'get',
#               'get',
#               'park',
#               'look',
#               'see',
#               'was',
#               'have',
#               'just',
#               'wish',
#               'had',
#               'didn’t.',
#               'felt',
#               'to',
#               'could',
#               'didn’t',
#               'didn’t',
#               'look',
#               'was',
#               'decided',
#               'mean,',
#               'decided',
#               'don’t',
#               'mean,',
#               'did',
#               'actually',
#               'don’t',
#               'realized,',
#               'wish',
#               'could',
#               'wish',
#               'could',
#               'really',
#               'really',
#               'walk',
#               'love',
#               'love',
#               'wish',
#               'could',
#               'can’t.',
#               'don’t',
#               'can’t',
#               'started',
#               'wasn’t',
#               'finally',
#               'did',
#               'got',
#               'got',
#               'was',
#               'sent',
#               'was',
#               'was',
#               'do.',
#               'open',
#               'see',
#               'don’t',
#               'would',
#               'don’t',
#               'jump',
#               'run',
#               'don’t',
#               'said.',
#               'was',
#               'go',
#               'pick',
#               'need',
#               'was',
#               'did',
#               'drove',
#               'don’t',
#               'get',
#               'do.”',
#               'sign',
#               'feel',
#               'hand',
#               'look',
#               'see',
#               'barely',
#               'have',
#               'tell',
#               'kissed',
#               'was',
#               'emigrated',
#               'thought',
#               'let',
#               'wanted',
#               'think',
#               'can',
#               'didn’t',
#               'reply,',
#               'reply,',
#               'go',
#               'start',
#               'click',
#               'make',
#               'want',
#               'would',
#               'go',
#               'want',
#               'was',
#               'get',
#               'hear,',
#               'was',
#               'just',
#               'can’t',
#               'can’t',
#               'cut',
#               'was',
#               'was',
#               'was',
#               'couldn’t',
#               'was',
#               'really',
#               'don’t.',
#               'would',
#               'could',
#               'can’t',
#               'never',
#               'write',
#               'see',
#               'let',
#               'crushed',
#               'had',
#               'needed',
#               'called',
#               'was',
#               'hope',
#               'realized,',
#               'care',
#               'can’t',
#               'know',
#               'take',
#               'turn',
#               'look,',
#               'never',
#               'did',
#               'kept',
#               'never',
#               'never',
#               'would',
#               'get',
#               'submit',
#               'get',
#               'can’t.',
#               'can’t',
#               'crazy?”',
#               'was',
#               'write',
#               'see',
#               'walk',
#               'see',
#               'can’t',
#               'sit',
#               'get',
#               'sit',
#               'can',
#               'can',
#               'hear…',
#               'know',
#               'just',
#               'hear',
#               'am',
#               'redefined',
#               'thought.',
#               'look',
#               'could',
#               'was',
#               'start',
#               'had',
#               'stuck',
#               'tucked',
#               'walk',
#               'hear',
#               'was',
#               'live',
#               'was',
#               'couldn’t',
#               'was',
#               'wanted',
#               'said',
#               'pinch',
#               'run',
#               'call',
#               'call',
#               'call',
#               'can’t',
#               'can’t',
#               'run',
#               'see',
#               'cured',
#               'didn’t',
#               'love',
#               'love',
#               'love'],
#              'had': ['to',
#               'never',
#               'better',
#               'vision',
#               'a',
#               'it',
#               'to',
#               'to',
#               'a',
#               'a',
#               'yet',
#               'been',
#               'just',
#               'just',
#               'chemistry.',
#               'to',
#               'brownies,',
#               'was',
#               'bitten',
#               'a',
#               'said,',
#               'those',
#               'a',
#               'a',
#               'just',
#               'me',
#               'to',
#               'Jewish',
#               'it'],
#              'to': ['bring',
#               'do',
#               'go.',
#               'say.',
#               'my',
#               'America.',
#               'marry',
#               'the',
#               'the',
#               'know',
#               'no',
#               'the',
#               'go',
#               'India',
#               'finish',
#               'make',
#               'do',
#               'understand',
#               'die.',
#               'pay',
#               'live',
#               'see',
#               'hit',
#               'NPR.',
#               'the',
#               'Sacramento.',
#               'this',
#               'my',
#               'surprise',
#               'say',
#               'fight',
#               'be',
#               'your',
#               'school',
#               'India.',
#               'be',
#               'call',
#               'get',
#               'me',
#               'India',
#               'visit',
#               'go',
#               'get',
#               'your',
#               'the',
#               'school',
#               'tell',
#               'be',
#               'that',
#               'the',
#               'be,',
#               'war',
#               'pop',
#               'be',
#               'an',
#               'grad',
#               'get',
#               'a',
#               'put',
#               'get',
#               'adhere',
#               'the',
#               'adhere',
#               'this',
#               'my',
#               'pull',
#               'the',
#               'ring',
#               'be',
#               'marry!”',
#               'liberate',
#               'talk',
#               'get',
#               'change',
#               'be',
#               'change',
#               'appease',
#               'see?',
#               'change',
#               'do?',
#               'the',
#               'marry',
#               'marry',
#               'be',
#               'make',
#               'pick',
#               'have',
#               'the',
#               'die',
#               'girls?”',
#               'the',
#               'us.',
#               'the',
#               'fucking',
#               'clean',
#               'happen.',
#               'this',
#               'be',
#               'push',
#               'this',
#               'put',
#               'prove',
#               'her.',
#               'wake',
#               'be.”',
#               'be',
#               'be',
#               'be',
#               'be',
#               'a',
#               'go',
#               'a',
#               'Davis,',
#               'go',
#               'you.”',
#               'fire',
#               'talk',
#               'somebody!”',
#               'her',
#               'go.”',
#               'my',
#               'open',
#               'that.',
#               'ease',
#               'change',
#               'close',
#               'change',
#               'live',
#               'know',
#               'life',
#               'live',
#               'go',
#               'prom.”',
#               'prom?',
#               'the',
#               'the',
#               'the',
#               'happen.',
#               'the',
#               'fuck!”',
#               'my',
#               'me.',
#               'prom',
#               'play.',
#               'go',
#               'prom.”',
#               'go',
#               'prom.',
#               'sneak',
#               'jump',
#               'your',
#               'die,',
#               'go.',
#               'overkill',
#               'get',
#               'not',
#               'her',
#               'the',
#               'ring',
#               'go',
#               'go',
#               'prom',
#               'be',
#               'the',
#               'ruin',
#               'improvise.',
#               'go.',
#               'go.”',
#               'different',
#               'prom',
#               'African-Americans',
#               'this',
#               'pay?',
#               'be',
#               'talk',
#               'get',
#               'be',
#               'be',
#               'be',
#               'headline',
#               'the',
#               'make',
#               'give',
#               'be',
#               'the',
#               'the',
#               'Nashville',
#               'LA.',
#               'the',
#               'do',
#               'Kaiser',
#               'my',
#               'the',
#               'a',
#               'tell',
#               'be',
#               'this',
#               'a',
#               'protect',
#               'protect',
#               'be',
#               'do',
#               'be',
#               'feel,',
#               'three',
#               'three',
#               'hear.”',
#               'meet',
#               'New',
#               'me',
#               'the',
#               'be',
#               'talk',
#               'be',
#               'pursue',
#               'go',
#               'have',
#               'hear',
#               'talk',
#               'me',
#               'talk',
#               'me',
#               'me.',
#               'ask',
#               'move',
#               'be',
#               'take,',
#               'the',
#               'see',
#               'Aisha.”',
#               'audition',
#               'New',
#               'audition.',
#               'write',
#               'die',
#               'you',
#               'round',
#               'contain',
#               'the',
#               'back',
#               'New',
#               'the',
#               'the',
#               'go',
#               'LA.”',
#               'say.”',
#               'say',
#               'be',
#               'drop',
#               'find',
#               'lock'],
#              'bring': ['it', 'over', 'nothing'],
#              'it': ['back',
#               'feels',
#               'on',
#               'was',
#               'in',
#               'would',
#               'is,',
#               'is?”',
#               'mean?”',
#               'at',
#               'to',
#               'out?”',
#               'for',
#               'up,',
#               'right',
#               'came',
#               'is',
#               'up',
#               'doesn’t',
#               'right',
#               'right',
#               'our',
#               'happened,',
#               'was',
#               'always',
#               'was',
#               'wasn’t',
#               'to',
#               'academically',
#               'mandatory',
#               'down.',
#               'leading',
#               'up,',
#               'on',
#               'with',
#               'the',
#               'every',
#               'through.',
#               'again.”',
#               'all',
#               'great.',
#               'true',
#               'barely',
#               'to',
#               'was',
#               'go.',
#               'like',
#               'off',
#               'the',
#               'with',
#               'is.',
#               'is.',
#               'a',
#               'a',
#               'go?”',
#               'all',
#               'again.'],
#              'back': ['here.',
#               'to',
#               'to',
#               'and',
#               'where',
#               'over',
#               'to',
#               'in',
#               'into',
#               'and',
#               'and',
#               'and',
#               'and',
#               'and',
#               'and',
#               'there.',
#               'home',
#               'and',
#               'the',
#               'in',
#               'to'],
#              'here.': ['Netflix',
#               'Anybody',
#               'Like,',
#               'Yeah.',
#               'None',
#               'So',
#               'But',
#               'So',
#               'Life,',
#               'Six',
#               'Get',
#               'You’re',
#               'So'],
#              'Netflix': ['said,'],
#              'said,': ['“Where',
#               '“Describe',
#               '“Write',
#               '“Wait,',
#               '“Fuck',
#               '“I'],
#              '“Where': ['do', 'does'],
#              'do': ['you',
#               'the',
#               'you',
#               'everything',
#               'I',
#               'everything…\nI',
#               'that.”',
#               'what',
#               'you',
#               'this',
#               'you',
#               'this?”',
#               'I',
#               'we',
#               'this.',
#               'we',
#               'what',
#               'this',
#               'not',
#               'you',
#               'you',
#               'I',
#               'that.',
#               'this',
#               'that.',
#               'this.”',
#               'you',
#               'you',
#               'that,',
#               'it',
#               'what’s',
#               'you',
#               'you',
#               'you',
#               'that?”',
#               'that.”',
#               'anything',
#               'Seinfeld',
#               'you',
#               'that.'],
#              'you': ['want',
#               'guys.',
#               'know',
#               'and',
#               'guys',
#               'find',
#               'guys.',
#               'heard',
#               'later',
#               'telling',
#               'get?',
#               'get?',
#               'guys',
#               'laughing?',
#               'don’t',
#               'do.',
#               'guys',
#               'seen',
#               'fucking',
#               'kidding',
#               'know',
#               'to',
#               'know',
#               'forget?”',
#               'here.',
#               'could',
#               'have',
#               'can',
#               'that',
#               'are',
#               'are.”',
#               'and',
#               'do',
#               'go,',
#               'take',
#               'guys',
#               'getting',
#               'think',
#               'got',
#               'don’t.',
#               'have',
#               'so',
#               'do',
#               'the',
#               'are',
#               'go,',
#               'guys',
#               'push',
#               'know,',
#               'bald',
#               'want',
#               'want',
#               'fucking',
#               'ever',
#               'live',
#               'had',
#               'had',
#               'want,',
#               'ask',
#               'talk',
#               'kill',
#               'do,',
#               'sand',
#               'live,',
#               'ever',
#               'see',
#               'saying',
#               'come',
#               'pay',
#               'your',
#               'go,',
#               'return',
#               'want',
#               'want.',
#               'experience',
#               'want',
#               'mean?”',
#               'just',
#               'guys',
#               'want',
#               'don’t',
#               'guys',
#               'like?',
#               'into?”',
#               'over',
#               'guys',
#               'know',
#               'should…”',
#               'say',
#               'out.”',
#               'guys',
#               'to',
#               'have',
#               'know,',
#               'go',
#               'go',
#               'understand',
#               'come',
#               'need',
#               'a',
#               'see',
#               'see',
#               'but',
#               'know,',
#               'dick.”',
#               'know,',
#               'move',
#               'couldn’t',
#               'have',
#               'first',
#               'get',
#               'want',
#               'know',
#               'know,',
#               'lemons,',
#               'some',
#               'ever',
#               'need?”',
#               'did.',
#               'his',
#               'forgive',
#               'go',
#               'would',
#               'have',
#               'make',
#               'know',
#               'get',
#               'can',
#               'been?”',
#               'kidding',
#               'next',
#               'so',
#               'see',
#               'going',
#               'know',
#               'had',
#               'know',
#               'act',
#               'do',
#               'know',
#               'know',
#               'would',
#               'is',
#               'kept',
#               'never',
#               'carry',
#               'say?”',
#               'make',
#               'doing?',
#               'hunting',
#               'to',
#               'and',
#               'hit',
#               'and',
#               'to',
#               'have',
#               'write',
#               'when',
#               'need',
#               'guys',
#               'believe',
#               'crazy?',
#               'realize',
#               'how',
#               'done?”',
#               'heard',
#               'doing?”',
#               'for',
#               'going?”',
#               'Monday,',
#               'work',
#               'Monday,',
#               'got',
#               'know',
#               'get',
#               'go',
#               'guys.',
#               'guys.'],
#              'want': ['to',
#               'to',
#               'that',
#               'to',
#               'that',
#               'a',
#               'my',
#               'to',
#               'to',
#               'to',
#               'to',
#               'me',
#               'me',
#               'me',
#               'to',
#               'to',
#               'to',
#               'this',
#               'to',
#               'to',
#               'it?',
#               'brownies?”',
#               'you',
#               'us',
#               'to',
#               'to',
#               'to',
#               'some',
#               'to',
#               'you',
#               'to',
#               'to',
#               'that',
#               'you'],
#              'the': ['special?',
#               'claps.',
#               'Rings',
#               'Rings.',
#               'ring,',
#               'streets',
#               'iPhone',
#               'line.',
#               'man',
#               'rest',
#               'US',
#               'only',
#               'States,',
#               'rappers',
#               'whole',
#               'ending?”\nSo',
#               'States,',
#               'first',
#               'two',
#               'unconditional',
#               'photo',
#               'only',
#               'only',
#               'grocery',
#               'aisles,',
#               'soda',
#               'coast',
#               'shit',
#               'liberal',
#               'way',
#               'arm',
#               'body.',
#               'mind.',
#               'show',
#               'kid',
#               'veins.',
#               'Scripps',
#               'great',
#               'US…',
#               'morning.',
#               'Camry.”',
#               'Camry,',
#               'entire',
#               'one',
#               'Toys',
#               'blue',
#               'door',
#               'bathroom.”',
#               'toilet?',
#               'mom',
#               'backpack,',
#               'gun',
#               'happiest',
#               'visa',
#               'visa',
#               'brother.”',
#               'fuck',
#               'dinner',
#               'language…',
#               'playground.',
#               'boys’',
#               'bathroom.',
#               'kids',
#               'urinal',
#               'US.',
#               'living',
#               'box.”',
#               'box',
#               'flaps,',
#               'flaps.',
#               'table.',
#               'audacity',
#               'world',
#               'block.”',
#               'cement.',
#               'paint',
#               'right',
#               'bike.',
#               'patter',
#               'first',
#               'American',
#               'one',
#               'Montagues',
#               'difference?',
#               'same.”',
#               'alphabet.',
#               'wall.”',
#               'older',
#               'motherland.',
#               'weird',
#               'side?',
#               'troops,',
#               'Camry,',
#               'door,',
#               'doorbell,',
#               'sentence',
#               'killer',
#               'sky.',
#               'time.',
#               'ball',
#               'time',
#               'Camry,',
#               'time.”',
#               'love',
#               'internet',
#               'phone.',
#               'house,',
#               'phone',
#               'land.',
#               'house.',
#               'question?”',
#               'question,',
#               'way',
#               'way',
#               'outside',
#               'leader',
#               'household.',
#               'phone.',
#               'second',
#               'mortality',
#               'windows',
#               'Camry',
#               'trees,',
#               'bushes…',
#               'middle',
#               'street,',
#               'middle',
#               'road',
#               'road',
#               'price',
#               'American',
#               'audacity',
#               'guy',
#               'cashier',
#               'bigger',
#               'bigots.’',
#               'house',
#               'burbs,',
#               'needle',
#               'first',
#               'sandbox.',
#               'color',
#               'universe',
#               'third',
#               'video',
#               'way.',
#               'privilege',
#               'basketball',
#               'day,',
#               'internet',
#               'phone,',
#               'phone!',
#               'door.',
#               'dinner',
#               'living',
#               'car.',
#               'door.',
#               'door,',
#               'night.',
#               'rules.',
#               'rules.',
#               'shaadi?”',
#               'entire',
#               'prom?',
#               'board,',
#               'big',
#               'board.',
#               'chances?”',
#               'same',
#               'second',
#               'tombstone.',
#               'JC',
#               'Michael',
#               'MJ',
#               'side',
#               'roof.',
#               'sun',
#               'chains.',
#               'corsage.',
#               'doorstep,',
#               'doorbell',
#               'American',
#               'door.',
#               'nicest',
#               'dance.”',
#               'same',
#               'following',
#               'class',
#               'new',
#               'last',
#               'most',
#               'way',
#               'collateral',
#               'clock',
#               'Other.',
#               'employees,',
#               'street,',
#               'shitty',
#               'Heisenberg',
#               'same',
#               'airport.',
#               'internet',
#               'club,',
#               'airport.',
#               'streets',
#               'hospital.',
#               'Comedy',
#               'Comedy',
#               'hospital',
#               'clipboard',
#               'doctor.',
#               'last',
#               'hospital.',
#               'prom',
#               'bigger',
#               'time.',
#               'past.',
#               'advice',
#               'alphabet?',
#               'alphabet?',
#               'alphabet,',
#               'entire',
#               'Rajesh',
#               'advice',
#               'lips',
#               'door,',
#               'door,',
#               'street.',
#               'adults',
#               'same',
#               'color',
#               'past.',
#               'reason',
#               'question',
#               'way',
#               'American',
#               'restaurant',
#               'subway',
#               'restaurant.',
#               'most.',
#               'oil',
#               'show',
#               'atheist',
#               'Japanese.',
#               'Muslim',
#               'hero',
#               'hero',
#               'Muslim',
#               'piece,',
#               'door:',
#               'hallway,',
#               'old',
#               'way',
#               'desk.',
#               'Caribbean,',
#               'tunnel',
#               'guests',
#               'light,',
#               'opportunity.”',
#               'door,',
#               'only',
#               'greatest',
#               'cure'],
#              'special?': ['LA,'],
#              'LA,': ['Chicago,', 'Chicago,'],
#              'Chicago,': ['New', 'Nashville,', 'to'],
#              'New': ['York?”',
#               'York.',
#               'York.',
#               'York',
#               'York…',
#               'York,',
#               'York.”',
#               'York',
#               'York,',
#               'York.',
#               'York.',
#               'York.'],
#              'York?”': ['I'],
#              'was': ['like,',
#               'a',
#               'that',
#               'like',
#               'like,',
#               'just',
#               'a',
#               'a',
#               'my',
#               'like,',
#               'like,',
#               'like,',
#               'like,',
#               'very',
#               'like',
#               'breakdancing,',
#               'like,',
#               'like',
#               'like,',
#               'like,',
#               'saying.',
#               'like,',
#               'her',
#               'turning',
#               'my',
#               'looking',
#               'created',
#               'going',
#               'a',
#               'our',
#               'like,',
#               'in',
#               'like,',
#               'born',
#               'under',
#               'the',
#               'under',
#               'like,',
#               'fucking',
#               'like',
#               'all',
#               'all',
#               'like,',
#               'peeling.',
#               'one',
#               'like,',
#               'a',
#               'like,',
#               'like,',
#               'like,',
#               'like,',
#               'like,',
#               'your',
#               'that',
#               'getting',
#               'nine.”',
#               'like,',
#               'a',
#               'like,',
#               'like,',
#               'crazy',
#               'wondering,',
#               'like,',
#               'like,',
#               'like,',
#               'like,',
#               'I',
#               'like,',
#               'like,',
#               'like,',
#               'like,',
#               'like,',
#               'like,',
#               'like,',
#               'like,',
#               'like,',
#               'like,',
#               'white,',
#               'like,',
#               'ride',
#               'for',
#               'so',
#               'afraid',
#               'like,',
#               'like,',
#               'like,',
#               'like,',
#               'like,',
#               'like,',
#               'like,',
#               'like,'],
#              'like,': ['“Nah,',
#               '“You',
#               'Seema',
#               '“A',
#               'immigrants',
#               '“You',
#               'super',
#               '“Hanson',
#               '“Jesus…”',
#               '“Ah.”',
#               '“Oh,',
#               '“Ah!”',
#               '“Hey,',
#               '“I’m',
#               '“Do',
#               '“Oh,',
#               '“Home',
#               '“Why',
#               '“Hasan,',
#               '“Why',
#               '“Dad,',
#               '“Hang',
#               '“When',
#               '“I’m',
#               '“Alright.',
#               '“No,',
#               '“Who',
#               '“Build',
#               '“I',
#               '“You',
#               '“No,',
#               '“Yo,',
#               '“Uh!',
#               '“Hey!',
#               '“No!',
#               '“Yo,',
#               '“Hasan',
#               '“Hey,',
#               '“Everybody',
#               '“Do',
#               '“Mom',
#               '“Take',
#               '“Fuck',
#               '“Hasan',
#               '“Eat',
#               '“Man…',
#               '“Oh,',
#               'she',
#               '“Ugh!”',
#               '“What’s',
#               '“Oh!',
#               '“No',
#               '“Oh,',
#               '“That’s',
#               '“If',
#               '“Log',
#               '“Wait,',
#               '‘You’re',
#               '“Maybe',
#               '“Dad,',
#               '“I’m',
#               '“Okay,',
#               '“Hasan,',
#               'not',
#               '“Why',
#               '“We',
#               '“I’m',
#               '‘Let’s',
#               '“What?',
#               '“Oh,',
#               '“an',
#               '“I',
#               '“I',
#               '“Hey…',
#               '“It’s',
#               '“Hey,',
#               '“You',
#               '“Hey,',
#               '“What?”',
#               '“Hey,',
#               '“I’ve',
#               '“No,',
#               '“We',
#               'go',
#               '“Don’t',
#               '“You',
#               '“Oh,',
#               '“Hey.',
#               '“It',
#               '“Yeah,',
#               '“I',
#               '“Are',
#               '“I',
#               '“No,',
#               '“All',
#               '“Hanson,',
#               '“Whatever,',
#               '“Oh!',
#               '“Wait',
#               '“What’s',
#               '“Listen,',
#               '“Yes,',
#               '“No!”',
#               '‘Even',
#               '“Dad,',
#               '“Wait.',
#               '“Oh,',
#               '“No,',
#               '“Everybody',
#               '“So,',
#               '“Yeah,',
#               '“Yeah,',
#               '“Maybe',
#               '“Uh…',
#               '“Mexicans,',
#               '“Babe,',
#               '“Yo,',
#               '“I’m',
#               '“I',
#               '“Fuck',
#               '“I',
#               '“They',
#               '“If',
#               '“Why?”',
#               '“Fuck',
#               '“Do',
#               '“Tell',
#               '“Yeah,',
#               '“Stop',
#               '“Oh,',
#               '“Alright,',
#               '“You',
#               '“I',
#               '“I',
#               '“I',
#               '‘No.',
#               '“What',
#               '“I',
#               '“Dude,',
#               '“Next',
#               '“Yeah,',
#               '“I’m',
#               '“Oh,',
#               '“These',
#               '“Are',
#               '“No,',
#               '“We’ll',
#               '“Hey,',
#               '“Positive',
#               '“No!”',
#               '“Have',
#               '“I',
#               '“Oh,',
#               '“Why?”',
#               '“Oscar',
#               '“Yeah,',
#               '“No!'],
#              '“Nah,': ['son.'],
#              'son.': ['Davis', 'Reply.'],
#              'Davis': ['California.”', 'was,', 'to'],
#              'California.”': ['[cheering,'],
#              '[cheering,': ['whooping]', 'applause]', 'whooping]\nNow'],
#              'whooping]': ['This',
#               '“No',
#               'That’s',
#               'But',
#               'I',
#               'you',
#               '“What’s',
#               'Then'],
#              'This': ['has,',
#               'has',
#               'is',
#               'is',
#               'kid',
#               'is',
#               'is',
#               'is',
#               'is',
#               'is',
#               'is',
#               'ain’t',
#               'just',
#               'is',
#               'is',
#               'year',
#               'is',
#               'is',
#               'isn’t',
#               'is'],
#              'has,': ['um…'],
#              'um…': ['This'],
#              'has': ['been',
#               'a',
#               'to',
#               'a',
#               'a',
#               'ever',
#               'this',
#               'been',
#               'passed,',
#               'to',
#               'to',
#               'taught',
#               'to',
#               'a',
#               'all',
#               'a'],
#              'been': ['a',
#               'slapped',
#               'like,',
#               'warring',
#               'killing',
#               'trapped',
#               'going',
#               'more',
#               'to',
#               'cut',
#               'my',
#               'dressed,',
#               'asking',
#               'there.',
#               'there.'],
#              'a': ['very',
#               'very',
#               'reverse',
#               'ring',
#               'very',
#               '90-hour',
#               'fuck',
#               'god-damn',
#               'town',
#               'small',
#               'buzz',
#               'camera.”',
#               'woman',
#               'good',
#               'ninja,',
#               'communist?',
#               'problem.',
#               'big',
#               'lot',
#               'weird',
#               '12-hour',
#               'little',
#               'real',
#               'real',
#               'white',
#               'birthday',
#               'spelling',
#               'few',
#               'slap.',
#               'generational',
#               'finite',
#               'doctor?',
#               'hand.',
#               'white',
#               'big',
#               'six-year-old.',
#               'Ghostbusters',
#               'Ghostbuster?”',
#               'brown',
#               'toy.',
#               'family.',
#               'big',
#               'broken',
#               'Salwar',
#               'mushroom',
#               'sister.',
#               'secret',
#               'little',
#               'bunch',
#               'term',
#               'father,',
#               'hard',
#               'beautiful,',
#               'personality.”',
#               'curb.',
#               'wheelie.',
#               'dick.”',
#               'refugee',
#               'refugee.',
#               'comedian.',
#               'girl',
#               'Hindu',
#               'statue',
#               'cartoon',
#               'good',
#               'Hall',
#               'brown',
#               'star',
#               'doctor!”',
#               'voice',
#               'PhD.',
#               'comedian.”',
#               'great',
#               'period',
#               'choice',
#               'girl',
#               'girl',
#               'virgin.”',
#               'question.',
#               'firewall',
#               'voice.',
#               'darapok.',
#               'scaredy-cat.',
#               'barbershop.',
#               'word.',
#               'doctor,',
#               'house',
#               'super',
#               'dream.',
#               'dream.”',
#               'dream,',
#               'Fair',
#               'sunburn.',
#               'great',
#               'shit',
#               'huge',
#               'club',
#               'career',
#               'lie.',
#               'school',
#               'lover.',
#               'school',
#               'rooster.',
#               'kiss.',
#               'fucking',
#               'group',
#               'life',
#               'bracket',
#               'G.',
#               'good',
#               'great',
#               'white',
#               'corsage',
#               'lot',
#               'good',
#               'ride',
#               'ride',
#               'generational',
#               'cliché.',
#               'dick.”',
#               'show',
#               'lot',
#               'white',
#               'fuck?',
#               'police',
#               'tax',
#               'fuck,',
#               'race',
#               'time',
#               'comedian.”',
#               'journalist.”',
#               'chance',
#               'comedy',
#               'big',
#               'lot',
#               'headliner.',
#               'little',
#               'lot',
#               'good',
#               'heart',
#               'heart',
#               'quintuple',
#               'set',
#               'set',
#               'death',
#               'person',
#               'girl.',
#               'school',
#               'gang,',
#               'girl',
#               'drug',
#               'very',
#               'box',
#               'box',
#               'Pizza',
#               'small',
#               'better',
#               'public',
#               'relationship',
#               'gig',
#               'sudden,',
#               'darapok',
#               'lot.',
#               'parent',
#               'Voldemort',
#               'deposit',
#               'good',
#               'psycho?',
#               'shit',
#               'co-sign.',
#               'box',
#               'question.',
#               'statement.',
#               'tape.',
#               'call.',
#               'mere',
#               'fucking',
#               'few',
#               'second',
#               'tell-tale',
#               'wrap.',
#               'giant',
#               'previous',
#               'Russian',
#               'voice.',
#               'purpose.',
#               'cure',
#               'vaccine'],
#              'very': ['good',
#               'heavy',
#               'different',
#               'conditional.',
#               'emo.',
#               'heavy',
#               'simple.',
#               'good.',
#               'beautiful',
#               'controlling.'],
#              'good': ['year',
#               'personality.',
#               'point.',
#               'kid.',
#               'fit.',
#               'people',
#               'fit.”',
#               'person',
#               'enough.',
#               'enough.”'],
#              'year': ['for', 'down,', 'of', 'wouldn’t'],
#              'for': ['me.',
#               'love,',
#               'me.”',
#               'the',
#               'that',
#               'a',
#               'the',
#               'this',
#               'the',
#               'immigrants.”',
#               'her',
#               'her',
#               'you.',
#               'one',
#               'acceptance',
#               'me',
#               'centuries.',
#               'centuries.',
#               'Naila',
#               'centuries.',
#               'this.”',
#               'me.',
#               'being',
#               'me,',
#               'me.',
#               'white',
#               'that',
#               'dinner.”',
#               'everyone',
#               '30?',
#               'nerds.',
#               'each',
#               'being',
#               'the',
#               'us',
#               'us',
#               'halal',
#               'me.',
#               'life.',
#               'just',
#               'just',
#               'a',
#               'it.”',
#               'you.',
#               'me,',
#               'me,',
#               'you.”',
#               'a',
#               'a',
#               'just',
#               'you',
#               'The',
#               'The',
#               'the',
#               'racism.',
#               'cancer,',
#               'Ebola.'],
#              'me.': ['I',
#               '[laughter]',
#               'Turn',
#               'I',
#               '“Hasan',
#               '“Happy',
#               'Isn’t',
#               'Why',
#               '“Oh,',
#               'She',
#               '“Hello,',
#               '“You',
#               'Do',
#               'And',
#               'I',
#               'Not',
#               'This',
#               'She’s',
#               '“Wow,',
#               'Gotham',
#               'I',
#               '“Are',
#               'God',
#               'Now,',
#               'Fuck',
#               'She’s',
#               'When',
#               'Steve',
#               'I’m,'],
#              'recently': ['got'],
#              'got': ['married,',
#               'a',
#               'slapped',
#               'this',
#               'what',
#               'that',
#               'married',
#               'to',
#               'to',
#               'all',
#               'to',
#               'customers.',
# ...
#               'we’re',
#               'I’m',
#               'you'],
#              'up!': ['Get'],
#              'Camry.”': ['The'],
#              'car': ['of', 'almost'],
#              'choice.': ['We', 'I'],
#              'Camry,': ['we’re', 'we’re', 'then'],
#              'driving': ['from', 'to'],
#              'Sacramento.': ['There’s'],
#              'There’s': ['one', 'brown'],
#              'mall': ['in'],
#              'entire': ['area.', 'time.', 'class.', 'alphabet.', 'career'],
#              'area.': ['Arden.'],
#              'Arden.': ['We'],
#              'intersection,': ['and'],
#              'left,': ['and', 'I'],
#              'place': ['every'],
#              'every': ['kid',
#               'brown',
#               'time',
#               'generation',
#               'time',
#               'Trayvon',
#               'day.',
#               'generation'],
#              'dreams': ['about.'],
#              'about.': ['Toys'],
#              'Toys': ['‘R’', '‘R’'],
#              '‘R’': ['Us.', 'Us', 'Us”'],
#              'Us.': ['I', 'Clothes,'],
#              'shit!': ['Dad', 'Send'],
#              'Us': ['catalog'],
#              'catalog': ['on'],
#              'wall.': ['He'],
#              'vision': ['board.', 'as'],
#              'board.': ['He', 'Last'],
#              'blue': ['BMX', 'BMX', 'BMX', 'it'],
#              'BMX': ['bike', 'bike.', 'bike…', 'bikes'],
#              'bike': ['I', 'goes', 'over', 'to'],
#              'wanted.': ['He’s'],
#              'here': ['to',
#               'down,',
#               'up.',
#               'this',
#               'stealing',
#               'with',
#               'to',
#               'to'],
#              'surprise': ['me.'],
#              'Turn': ['left.', 'left.'],
#              'left.': ['Turn', 'Turn…'],
#              'Turn…': ['left.”'],
#              'left.”': ['Then'],
#              'turns': ['right,'],
#              'right,': ['and'],
#              '“Home': ['Depot?'],
#              'Depot?': ['No!”'],
#              'No!”': ['I’m'],
#              'here?': ['Do', 'I’m'],
#              'day': ['it', 'he', 'I', 'I'],
#              'is?”': ['“It’s'],
#              '“It’s': ['Saturday.”', 'a', 'about'],
#              'Saturday.”': ['“No,'],
#              'Did': ['you'],
#              'forget?”': ['He’s'],
#              'forget': ['that', 'about'],
#              'birthday?': ['That’s'],
#              'door': ['handle'],
#              'handle': ['for'],
#              'bathroom.”': ['[laughter]'],
#              'toilet?': ['You'],
#              'shitting': ['on'],
#              'dreams.”': ['I', '[laughter]', 'Then'],
#              'say': ['that.',
#               'that.',
#               'we',
#               'that.',
#               'that.',
#               'anything.',
#               'every',
#               'something!”',
#               'that…',
#               'you',
#               'anything.',
#               'anything.”',
#               'that?',
#               'anything.”',
#               'anything.',
#               'anything.”',
#               'anything.',
#               'anything.',
#               'was,'],
#              'gotten': ['a', 'a', 'in'],
#              'slap.': ['I'],
#              'wanted': ['to', 'it', 'to', 'us', 'to', 'to', 'to', 'to', 'to'],
#              'realized': ['there’s', 'I'],
#              'there’s': ['a', 'a'],
#              'generational': ['gap', 'thing.', 'change'],
#              'gap': ['between'],
#              'between': ['us', 'being'],
#              'fight': ['with', 'me.'],
#              'parents,': ['and', 'and'],
#              'finite': ['number'],
#              'number': ['of', 'one.'],
#              'hands': ['you'],
#              'play.': ['You', 'You’re'],
#              'doctor?': ['That’s'],
#              'hand.': ['Marry', '[laughter,', 'I'],
#              'Marry': ['a'],
#              'girl?': ['Boom!', 'Thank', 'Who'],
#              'Boom!': ['That’s', 'Twenty-two-time', 'I'],
#              '[laughter,': ['applause]',
#               'applause]',
#               'applause]',
#               'applause,',
#               'applause,',
#               'applause]',
#               'applause]'],
#              'bike.”': ['But', 'And'],
#              '“Hang': ['on'],
#              'cards.': ['You’ll', 'So'],
#              'You’ll': ['need', 'never'],
#              'later.”': ['Like,'],
#              'as': ['a', 'an', 'soon', 'I', 'I', 'they', 'he', 'fuck.'],
#              'six-year-old.': ['And'],
#              'visit,': ['and'],
#              'game.': ['One'],
#              'One': ['year,', 'of', 'night', 'night,', 'kid', 'day', 'shot,'],
#              'year,': ['she'],
#              'came': ['to', 'from.”', 'time', 'before'],
#              'school': ['and',
#               'with',
#               'a',
#               'dance,',
#               'friend',
#               'dance,',
#               'prom'],
#              'Ghostbusters': ['proton', 'proton'],
#              'proton': ['pack.', 'pack.'],
#              'pack.': ['The', 'I’m'],
#              'wheelie': ['thing,'],
#              'thing,': ['the'],
#              'backpack,': ['the'],
#              'gun': ['that'],
#              'catches': ['ghosts…'],
#              'ghosts…': ['Literally'],
#              'Literally': ['shut'],
#              'shut': ['Pioneer'],
#              'Pioneer': ['down.'],
#              'Kids': ['were', 'start'],
#              'losing': ['their', 'hope.'],
#              'minds.': ['“What?'],
#              'Saddam': ['Hussein’s'],
#              'Hussein’s': ['a'],
#              'Ghostbuster?”': ['“Yeah,'],
#              '“Yeah,': ['I’m', 'you', 'what', 'you', 'let’s', 'let’s', 'I’m'],
#              'Ghostbuster.': ['Deal'],
#              'Deal': ['with'],
#              'it.”': ['One', 'I', 'But', '“See', 'A'],
#              'happiest': ['days'],
#              'days': ['of', 'before', 'where'],
#              'India.': ['That’s', 'We’ve'],
#              'toy.': ['I'],
#              'family.': ['I', 'I'],
#              'emo.': ['I'],
#              'Drake.': ['I'],
#              'missed': ['that'],
#              'girl.': ['“When', 'I', 'I', 'It’s', 'I’ll', 'She’s'],
#              '“When': ['is', 'the', 'the'],
#              'coming': ['back?', 'over.', 'at', 'out'],
#              'back?': ['I'],
#              'her': ['in',
#               'up.',
#               'out',
#               'first',
#               'first',
#               'first',
#               'birthday,',
#               'chappals.',
#               'big',
#               'navigate',
#               'bike?',
#               'mind.”',
#               'cards',
#               'Hasan',
#               'in',
#               'family',
#               'place,',
#               'up',
#               'book,',
#               'book.',
#               'out.',
#               'arm',
#               'house.',
#               'shoulder,',
#               'having',
#               'off.',
#               'face',
#               'the',
#               'one',
#               'again.'],
#              'her.': ['I',
#               'I',
#               'And',
#               'But',
#               'First',
#               'Second',
#               'She',
#               'You’re'],
#              'girl': ['in',
#               'with',
#               'so',
#               'from',
#               'called',
#               'called',
#               'named',
#               'pregnant'],
#              'her,': ['Dad.',
#               'and',
#               'she',
#               'I',
#               'like,',
#               'and',
#               '“Please',
#               'and'],
#              'Dad.': ['She', 'How', 'Say'],
#              'used': ['to', 'to', 'underwear.'],
#              'phone.”': ['My'],
#              'dad’s': ['like,', 'looking', 'from'],
#              'visa': ['comes', 'comes'],
#              'through.”': ['“When', 'It’s'],
#              'deal.': ['I'],
#              'anyone': ['says.'],
#              'says.': ['It’s'],
#              'difficult': ['to'],
#              'country.': ['It’s'],
#              'broken': ['condom'],
#              'condom': ['where'],
#              'in!”': ['[laughter]'],
#              'Eight': ['years.', 'Mile.'],
#              'years.': ['August', 'A'],
#              'August': ['11th,'],
#              '11th,': ['1993.'],
#              '1993.': ['I’m'],
#              'excited.': ['I'],
#              'put': ['on',
#               'on',
#               'this',
#               'that',
#               'this',
#               'my',
#               'on',
#               'it',
#               'on',
#               'here'],
#              'standing': ['there.', 'there.', 'there…', 'there…', 'outside'],
#              'there.': ['Dad',
#               'Door',
#               'Phone',
#               'We’re',
#               'What',
#               'Who',
#               'When',
#               'Everyone’s,',
#               'And'],
#              'goes,': ['“Put',
#               '“Aisha,',
#               '“I',
#               '“Hasan…”',
#               '“Come',
#               '“Hasan,',
#               '“No…',
#               '“Hey,',
#               '“Hey,'],
#              '“Put': ['on'],
#              'clothes.”': ['I’m'],
#              '“Alright.': ['I'],
#              'ghostbuster.”': ['I'],
#              'Salwar': ['Kameez.'],
#              'Kameez.': ['I’m'],
#              'Door': ['opens.'],
#              'opens.': ['Dad'],
#              'walks': ['through.', 'through.', 'back', 'over', 'to'],
#              'through.': ['Mom', 'And', 'We’re'],
#              'Mom': ['walks', 'and'],
#              'immediately': ['behind'],
#              'behind': ['my', 'me.', 'me,'],
#              'mushroom': ['cut.'],
#              'cut.': ['She'],
#              'hugs': ['me.'],
#              '“Hasan': ['bhai!”',
#               'bhai!”',
#               'bhai!”',
#               'bhai!”',
#               'bhai,',
#               'bhai,',
#               'bhai,',
#               'Minhaj,',
#               'bhai,'],
#              'bhai!”': ['And', 'I’m', '“Get', 'All'],
#              'full': ['hover-hands'],
#              'hover-hands': ['mode,'],
#              'mode,': ['because'],
#              'idea': ['who', 'who'],
#              'who': ['this', 'you', 'is', 'is', 'I'],
#              'person': ['is.', 'I', 'again.', 'and'],
#              'is.': ['What', 'You’re', 'It’s', 'So', 'Middle', 'And'],
#              'happened': ['was,', 'I', 'in'],
#              'forth': ['to', 'for', 'in'],
#              'visit': ['my'],
#              'during': ['one', 'first', 'lunch.', 'March'],
#              'knocked': ['her'],
#              'up.': ['[shocked', 'I’ve', 'And', 'She'],
#              '[shocked': ['laughter]', 'laughter,', 'laughter]', 'laughter]'],
#              'sister.': ['But', 'I'],
#              'told': ['me', 'you', 'me!', 'his', 'my'],
#              '[uproarious': ['laughter]'],
#              'Remember': ['how'],
#              'secrets?': ['This'],
#              'secret': ['that', 'was,'],
#              'nobody': ['told'],
#              'me!': ['He'],
#              'says,': ['“Hug'],
#              '“Hug': ['her.”'],
#              'her.”': ['“You'],
#              'Maury': ['for'],
#              'immigrants.”': ['“Hasan,'],
#              'brother.”': ['I’m'],
#              'no!”': ['She'],
#              'breakdancing,': ['and'],
#              '“Who': ['the'],
#              'you?”': ['“You'],
#              'me?”': ['“I’ve', 'And', '[applause,'],
#              '“I’ve': ['no', 'got'],
#              'are.”': ['I'],
#              'hated': ['that', 'her.'],
#              'much.': ['I', 'It’s', 'You’ve', 'All', 'And'],
#              '“Build': ['that'],
#              'wall.”': ['I', 'And'],
#              'Republican.': ['I'],
#              'leveling': ['with'],
#              'dinner': ['table.', 'table.'],
#              'table.': ['“Look,', 'I', 'And', 'My', 'We’re'],
#              '“Look,': ['Mom,'],
#              'Mom,': ['Dad,', 'Dad,'],
#              'Dad,': ['let’s', 'Aisha,', 'I', 'I’ll', 'you’re', 'a'],
#              'Oh,': ['my', 'jeez.', 'no!', 'hello.'],
#              'God,': ['these', 'you', 'honey,', 'Rajesh'],
#              'these': ['brown', 'people', 'things', 'press', 'photos'],
#              'people…': ['Oh,', '[cheering]'],
#              'jeez.': ['Coming'],
#              'Coming': ['into'],
#              'house…': ['eating'],
#              'eating': ['our'],
#              'Fruit': ['Roll-Ups…'],
#              'Roll-Ups…': ['they'],
#              'speak': ['the', 'two', 'at'],
#              'language…': ['I'],
#              'tell': ['them',
#               'Dad.”',
#               'people',
#               'you?',
#               '18-year-old',
#               'him',
#               '18-year-old',
#               'him',
#               'him',
#               'him',
#               'them',
#               'you'],
#              'from.”': ['He’s'],
#              'family.”': ['I’m'],
#              'Mom.': ['You'],
#              'decided': ['to', 'not', 'not'],
#              'Angelina': ['Jolie'],
#              'Jolie': ['on,'],
#              'on,': ['and', 'Dad.'],
#              'over': ['this', 'there?', 'to', 'to', 'to', 'her', 'and', '18?'],
#              'FOB.': ['That’s'],
#              'daughters?': ['Every'],
#              'mother': ['makes'],
#              'daughter': ['quinceañera'],
#              'quinceañera': ['dress,'],
#              'dress,': ['chop'],
#              'chop': ['cuts.'],
#              'cuts.': ['Why?'],
#              'Why?': ['Princess', 'I'],
#              'Princess': ['from'],
#              'Toad': ['from'],
#              'I’ve': ['got',
#               'played',
#               'never',
#               'seen',
#               'never',
#               'ever',
#               'got',
#               'never',
#               'got',
#               'got',
#               'gotten',
#               'got'],
#              'following': ['me', 'Monday,'],
#              'around': ['on', 'the', 'like', 'like', 'and'],
#              'playground.': ['“Hasan'],
#              '“Yo,': ['kick', 'when', 'what’s', 'Facebook!'],
#              'kick': ['rocks!”'],
#              'rocks!”': ['I'],
#              'play': ['tetherball.'],
#              'tetherball.': ['“Hasan'],
#              '“Get': ['lost!”'],
#              'lost!”': ['Eventually,'],
#              'Eventually,': ['I'],
#              'run': ['to',
#               'outside',
#               'up',
#               'to',
#               'upstairs.',
#               'it',
#               'it',
#               'outside.',
#               'upstairs,'],
#              'boys’': ['bathroom.'],
#              'bathroom.': ['She', '“Hasan'],
#              'follows': ['me'],
#              'All': ['the',
#               'the',
#               'the',
#               'men',
#               'we',
#               'of',
#               'morning,',
#               'caps.'],
#              'urinal': ['are'],
#              '“Uh!': ['What’s'],
#              'Hasan-bye?”': ['I'],
#              'bunch': ['of'],
#              'Ryan': ['Lochtes.'],
#              'Lochtes.': ['Just'],
#              'traps.': ['[slow,'],
#              '[slow,': ['stupid'],
#              'stupid': ['voice]'],
#              'voice]': ['“Uh,', '“Seven'],
#              '“Uh,': ['I'],
#              'other': ['cultures,', 'for', 'people.'],
#              'cultures,': ['bro.'],
#              'bro.': ['What'],
#              'that?': ['What', 'That'],
#              'mean?”': ['It’s', '“I'],
#              'term': ['of'],
#              'endearment': ['in'],
#              'culture,': ['meaning', 'money.'],
#              'meaning': ['“brother”.'],
#              '“brother”.': ['“Shut'],
#              '“Shut': ['up,'],
#              'up,': ['Cody!”', 'and', 'and', 'we', 'we’ve', 'contain'],
#              'Cody!”': ['I'],
#              'took': ['that', 'her.'],
#              'anger': ['and'],
#              'channeled': ['it'],
#              '“Hey!': ['You’re'],
#              'sister.”': ['[gasps'],
#              '[gasps': ['in'],
#              'audience]': ['But'],
#              'couldn’t': ['understand', 'have', 'go', 'date', 'believe'],
#              'English.': ['[laughter,', 'She'],
#              'saying.': ['She'],
#              'starts': ['crying', 'talking', 'riffing,'],
#              'crying': ['and'],
#              '“No!': ['She’s', 'I'],
#              'Dad.”': ['Let’s'],
#              'focus': ['on'],
#              'important': ['here.'],
#              'didn’t.': ['And', 'We', 'The'],
#              ...})

# %%
import random

def generate_sentence(chain, count=40): #chain == dict
   
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += '.'
    return(sentence)

# %%
generate_sentence(hasan_dict)
# Out:
# 'Therapy is laughing so much choice.” We’re in the States, they were losing their minds. “What? ‘Good job’? Say what she changes her book, and brought you guys. I don’t speak at me. I’m, like, “Man… I’m signing this guy..'
